# %% [markdown]
# # Comfort Zone: motor de decaimiento y validación
#
# Ejecuta el autotest del módulo `comfort_zone.py` (7 tramos de decaimiento, filtro de ruido de 2,99 $) y la validación de la lógica RFM/CZ sobre el esquema de Online Retail II (`validate_cz.py`).
#
# **Cifras canónicas esperadas:** todos los tramos del decaimiento OK; validación de la CZ sobre esquema real superada.
#
# > Este notebook ejecuta el script canónico del paquete mediante `%run`, de modo que el código fuente es único y compartido entre la entrega en scripts y el entorno Jupyter. Los outputs guardados corresponden a la reproducción independiente del 7 de julio de 2026 en el equipo local (MacBook-Air.local).

# %%
# %run ../02_comfort_zone/comfort_zone.py
# Out:
# [Ejecutado 2026-07-07 21:46:00 | MacBook-Air.local | Python 3.12.7]
#
# Motor de Decaimiento: todos los tramos OK

# %%
# %run ../02_comfort_zone/validate_cz.py
# Out:
# [Ejecutado 2026-07-07 21:46:00 | MacBook-Air.local | Python 3.12.7]
#
# ...
# TRANSACCIONES DE PRUEBA (estructura Online Retail II canónica)
# ...
#     user_id  timestamp  amount
# U1_reciente 2026-05-23    20.0
# U1_reciente 2026-05-16    30.0
#  U1b_20dias 2026-05-08   100.0
#   U2_45dias 2026-04-13    40.0
#   U2_45dias 2026-04-08    60.0
#  U2b_50dias 2026-04-08    80.0
#   U3_80dias 2026-03-09   100.0
#  U4_150dias 2025-12-29   150.0
#  U4_150dias 2025-12-09   250.0
#  U5_300dias 2025-08-01   500.0
#  U6_400dias 2025-04-23    80.0
#    U7_ruido 2026-05-18    10.0
#    U7_ruido 2026-05-18     2.0
#    U7_ruido 2026-05-18     1.5
#
# Fecha de referencia: 2026-05-28  |  Total transacciones: 14
#
# ...
# FUNCIÓN DE DECAIMIENTO (escalonada)
# ...
#      0–14   días sin compra  ->  peso 100 %
#     15–30   días sin compra  ->  peso  90 %
#     31–45   días sin compra  ->  peso  70 %
#     46–60   días sin compra  ->  peso  50 %
#     61–90   días sin compra  ->  peso  30 %
# ...
