# %% [markdown]
# # Reproducción completa del pipeline SAAOIPO desde Jupyter
#
# Este notebook lanza en orden los cinco bloques de verificación del proyecto. Cada bloque tiene además su notebook individual (`01`–`05`) **con los outputs de la reproducción independiente del 7 de julio de 2026 (MacBook-Air.local) ya guardados, idénticos a la ejecución de referencia**, por lo que las cifras canónicas pueden consultarse sin ejecutar nada.
#
# - Duración total aproximada de la ejecución: 15–20 minutos (los dos tests A/B son los bloques largos).
# - Todos los scripts usan semilla fija: las cifras resultantes son idénticas en cada ejecución.
# - La regeneración del dataset (`01_generacion_datos/regenerate_pipeline.py`) no se incluye aquí por ser opcional: los parquet entregados ya son su salida determinista. Puede lanzarse con la celda final (comentada).

# %%
# %run ../02_comfort_zone/comfort_zone.py

# %%
# %run ../02_comfort_zone/validate_cz.py

# %%
# %run ../03_modelos_ml/model_comparison.py

# %%
# %run ../03_modelos_ml/kmeans_exploratorio.py

# %%
# %run ../04_pricing_simulacion/abtest_v4.py

# %%
# %run ../04_pricing_simulacion/abtest_robustez.py

# %%
# Opcional: regenerar el dataset completo (sobrescribe los parquet con salida idéntica, semilla fija)
# %run ../01_generacion_datos/regenerate_pipeline.py
