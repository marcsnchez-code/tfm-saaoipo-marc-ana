# %% [markdown]
# # Pruebas de robustez del test A/B
#
# Dos comprobaciones: (1) sistema dinámico restringido al catálogo común de 14 price points (igualdad total de precios) y (2) check con cz_raw (sin decaimiento).
#
# **Cifras canónicas esperadas:** +32,4 % con catálogo restringido; +74,3 % con cz_raw.
#
# > Este notebook ejecuta el script canónico del paquete mediante `%run`, de modo que el código fuente es único y compartido entre la entrega en scripts y el entorno Jupyter. Los outputs guardados corresponden a la reproducción independiente del 7 de julio de 2026 en el equipo local (MacBook-Air.local).

# %%
# %run ../04_pricing_simulacion/abtest_robustez.py
# Out:
# [Ejecutado 2026-07-07 21:46:16 | MacBook-Air.local | Python 3.12.7]
#
# A/B test — Pruebas de robustez | 71,429 jugadores | 40 semillas
#
# [1] Dinámico RESTRINGIDO al catálogo común (igualdad total de precios)
#     ARPU 64.82 -> 85.68 $ | uplift 32.4% | IC95% [30.2,34.6] | sig 100%
#     (memoria 4.6: ARPU ~85,7 $, +32,4 %)
#
# [2] Check con cz_raw (sin decaimiento) — confirma que cz_final es conservador
#     ARPU 156.43 -> 272.44 $ | uplift 74.3% | IC95% [72.4,76.2] | sig 100%
#     (referencia: +74,3 % reproducible, frente al +70,3 % con cz_final)
#
# Guardado: abtest_robustez.csv
