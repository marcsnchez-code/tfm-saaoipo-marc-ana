# %% [markdown]
# # K-Means exploratorio: contraste de la segmentación por tiers
#
# Análisis de clustering exploratorio (método del codo y Silhouette) usado como contraste de la segmentación operativa por tiers explícitos de LTV.
#
# **Cifras canónicas esperadas:** k=2 óptimo con Silhouette 0,772; cada cluster dominado por tiers contiguos de LTV.
#
# > Este notebook ejecuta el script canónico del paquete mediante `%run`, de modo que el código fuente es único y compartido entre la entrega en scripts y el entorno Jupyter. Los outputs guardados corresponden a la reproducción independiente del 7 de julio de 2026 en el equipo local (MacBook-Air.local).

# %%
# %run ../03_modelos_ml/kmeans_exploratorio.py
# Out:
# [Ejecutado 2026-07-07 21:46:07 | MacBook-Air.local | Python 3.12.7]
#
# Análisis exploratorio de segmentación con K-Means (contraste, no pilar)
#
# Jugadores pagadores analizados: 20,000
# Variables RFM: ['monetary', 'frequency', 'recency_days']
#
# === Exploración del número de clusters ===
#   k=2 | inertia=        36,708 | silhouette=0.772
#   k=3 | inertia=        21,734 | silhouette=0.423
#   k=4 | inertia=        16,029 | silhouette=0.434
#   k=5 | inertia=        11,836 | silhouette=0.379
#   k=6 | inertia=         9,514 | silhouette=0.350
#   k=7 | inertia=         8,092 | silhouette=0.346
#   k=8 | inertia=         7,104 | silhouette=0.327
#
# Gráfico guardado en: 06_graficos/fig_kmeans_codo_silhouette.png
#
# k con mayor Silhouette en el rango explorado: 2
#
# === Contraste cluster x tier (k=2) ===
# archetype  Megalodons  Mobys  Tier1  Tier2  Tier3  Whales
# cluster
# 0                 116      0      0      0      0     393
# ...
