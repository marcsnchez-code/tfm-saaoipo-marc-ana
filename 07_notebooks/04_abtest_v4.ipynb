# %% [markdown]
# # Test A/B simulado: estático vs dinámico (resultado principal)
#
# Simulación económica con 40 réplicas y asignación estratificada por tier, con análisis de sensibilidad al error de estimación de la CZ (±0/15/25/40 %).
#
# **Cifras canónicas esperadas:** uplift +70,3 % con ruido ±25 % (ARPU 64,8 → 110,2 $, IC95 % [67,6–73,0], significativo en el 100 % de réplicas); sensibilidad entre +57,7 % y +78,6 %.
#
# > Este notebook ejecuta el script canónico del paquete mediante `%run`, de modo que el código fuente es único y compartido entre la entrega en scripts y el entorno Jupyter. Los outputs guardados corresponden a la reproducción independiente del 7 de julio de 2026 en el equipo local (MacBook-Air.local).

# %%
# %run ../04_pricing_simulacion/abtest_v4.py
# Out:
# [Ejecutado 2026-07-07 21:46:10 | MacBook-Air.local | Python 3.12.7]
#
# A/B test v4 | DPR real vs CZ estimada con ruido | 71,429 jugadores
#
#    Ruido  ARPU base   ARPU dyn   Uplift           IC95%  % sig
# sin ruido      64.82     115.62    78.6%     [75.8,81.5]   100%
#     ±15%      64.82     113.72    75.7%     [72.9,78.5]   100%
#     ±25%      64.82     110.22    70.3%     [67.6,73.0]   100%
#     ±40%      64.82     102.05    57.7%     [55.1,60.2]   100%
#
# Guardado: abtest_v4_sensibilidad_ruido.csv
#     ±25%      64.82     110.22    70.3%     [67.6,73.0]   100%
#     ±40%      64.82     102.05    57.7%     [55.1,60.2]   100%
#
# Guardado: abtest_v4_sensibilidad_ruido.csv
