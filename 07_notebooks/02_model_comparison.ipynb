# %% [markdown]
# # Modelos de propensión: Random Forest vs XGBoost
#
# Entrena y compara los dos clasificadores de propensión de compra sobre las cuatro variables de comportamiento (sin variables de gasto, para evitar fuga de información).
#
# **Cifras canónicas esperadas:** AUC XGBoost 0,913 (seleccionado) vs Random Forest 0,885.
#
# > Este notebook ejecuta el script canónico del paquete mediante `%run`, de modo que el código fuente es único y compartido entre la entrega en scripts y el entorno Jupyter. Los outputs guardados corresponden a la reproducción independiente del 7 de julio de 2026 en el equipo local (MacBook-Air.local).

# %%
# %run ../03_modelos_ml/model_comparison.py
# Out:
# [Ejecutado 2026-07-07 21:46:03 | MacBook-Air.local | Python 3.12.7]
#
# Dataset: 71,429 jugadores | tasa de conversión: 28.0%
# Variables predictoras: ['age', 'sessions_per_week', 'avg_session_min', 'engagement_num']
#
# === COMPARACIÓN DE MODELOS (conjunto de test) ===
#        Modelo    AUC  Precision  Recall     F1
# Random Forest 0.8855     0.7433  0.6538 0.6957
#       XGBoost 0.9132     0.6745  0.7936 0.7292
#
# === AUC EN VALIDACIÓN CRUZADA (5 folds) ===
#   Random Forest: 0.8833 ± 0.0023
#   XGBoost:       0.9112 ± 0.0028
#
# === IMPORTANCIA DE VARIABLES ===
#          variable  Random Forest  XGBoost
#               age          0.176    0.033
# sessions_per_week          0.398    0.268
#   avg_session_min          0.291    0.155
#    engagement_num          0.135    0.544
